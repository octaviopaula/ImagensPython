# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Achando o Tamanho

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img1.png')

# %%
height = len(image)
print(height)
# Out:
# 4

# %%
width = len(image[0])
print(width)
# Out:
# 4

# %%
size = height * width
print(size)
# Out:
# 16

# %% [markdown]
# # Qual é a largura

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img8.png')

# %%
plt.imshow(image)

# %%
width = len(image[0])
print(width)
# Out:
# 15

# %% [markdown]
# # Qual é a altura

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img3.png')

# %%
plt.imshow(image)

# %%
height = len(image)
print(height)
# Out:
# 8

# %% [markdown]
# # Qual é o maior

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img5.png')

# %%
plt.imshow(image)

# %%
print(image.max())
# Out:
# 244

# %% [markdown]
# # Qual é o menor

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img2.png')

# %%
plt.imshow(image)

# %%
print(image.min())
# Out:
# 0

# %% [markdown]
# # Vermelhor

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img8.png')

# %%
plt.imshow(image)

# %%
for line in image:
  for r, g, b in line:
    print(r)

# %% [markdown]
# # Da cor do mar

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img8.png')

# %%
plt.imshow(image)

# %%
for pixel in image:
  for r, g, b in pixel:
    if r < 100 and g < 100 and b > 150:
      p = pixel
      print(p)
# Out:
# [[201 128 170]
#  [ 79 173 173]
#  [221  16 152]
#  [ 22 197 112]
#  [ 75 250 209]
#  [229 242  90]
#  [222 186 103]
#  [ 70  16 205]
#  [154 143 176]
#  [ 19 102 102]
#  [148 252   0]
#  [ 47 109  61]
#  [  8 183 121]
#  [ 50 175  95]
#  [ 35  68  60]]
# [[217  79 204]
#  [176 167 220]
#  [243  49 160]
#  [ 60  53 101]
#  [122 173 254]
#  [ 89  43 158]
#  [226 165 231]
#  [253  68 206]
#  [211 100  98]
#  [171  76 180]
#  [117  34  56]
#  [ 92  42 231]
#  [109 112 226]
#  [ 12  98  13]
#  [152 119 106]]
# [[217  79 204]
#  [176 167 220]
#  [243  49 160]
#  [ 60  53 101]
#  [122 173 254]
#  [ 89  43 158]
#  [226 165 231]
#  [253  68 206]
#  [211 100  98]
#  [171  76 180]
#  [117  34  56]
#  [ 92  42 231]
#  [109 112 226]
#  [ 12  98  13]
#  [152 119 106]]
# [[242 127  40]
#  [113  24 239]
#  [136  59 189]
#  [109 107  25]
#  [136  59 201]
#  [198 135 221]
#  [158 193 132]
#  [ 51   4 122]
#  [  9   3  31]
#  [ 25  71 163]
#  [148 101 218]
#  [126 107 175]
#  [ 92 126 100]
# ...

# %% [markdown]
# # Media

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img8.png')

# %%
plt.imshow(image)

# %%
height = len(image)
width = len(image[0])
size = height * width
p = size / 2
print(p)
# Out:
# 75.0

# %% [markdown]
# # Media RGB

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img1.png')

# %%
plt.imshow(image)

# %%
for line in image:
  for r, g, b in line:
    p=r
    p=g
    p=b
    resul = p / 3
    print(int(resul))

# %% [markdown]
# # Pixel do meio

# %%
image = io.imread('http://ifelseonline.com.br/img/exercises/ifelse_img1.png')

# %%
plt.imshow(image)

# %%
for line in image:
  for line in range(0,3):
    for r, g, b in pixel:
      r=255
      g=255
      b=255

# %%
plt.imshow(image)

# %% [markdown]
# # Goomba

# %%
image = io.imread('https://pm1.narvii.com/6682/e5b04ad5265ebfd5dac14d36250a322895089cd1_hq.jpg')

# %%
plt.imshow(image)

# %%
image[4][3] = [255,0,0]
image[4][4] = [255,0,0]
image[5][5] = [255,0,0]
image[6][5] = [255,0,0]
image[7][5] = [255,0,0]
image[6][6] = [255,0,0]
image[6][7] = [255,0,0]
image[6][8] = [255,0,0]
image[6][9] = [255,0,0]
image[7][10] = [255,0,0]
image[5][10] = [255,0,0]
image[6][10] = [255,0,0]
image[4][11] = [255,0,0]
image[4][12] = [255,0,0]

# %%
plt.imshow(image)
